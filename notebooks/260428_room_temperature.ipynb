# %% [markdown]
# # Author Information

# %% [markdown]
# Author: Alessandra Guarriello
#
# Email: alessandra.guarriello@unibe.ch

# %% [markdown]
# ## Sub header
#
# * list item
# * list item

# %% [markdown]
# # Analysis Start

# %%
room_temperature = 34/3

# %%
room_temperature
# Out:
# 11.333333333333334

# %%
room_temperature * 5
# Out:
# 56.66666666666667
